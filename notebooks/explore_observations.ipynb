# %% [markdown]
# # Explore Observations
# Use this notebook to inspect raw game observations and understand the state space.

# %%
import json
import numpy as np

# Load a sample observation
# obs = json.load(open('logs/sample_obs.json'))
# print(obs)
